# %% [markdown]
# ## testing out the deck

# %%
from utils import deck
from pathlib import Path

# %%
base_deck = deck.deck_reader("../input_data/base_deck_copy.json")
print(len(base_deck.cards))
# Out:
# 45
