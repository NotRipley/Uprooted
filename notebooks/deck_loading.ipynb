# %% [markdown]
# ## testing out the deck

# %%
from src import deck
from pathlib import Path

# %%
base_deck = deck.Deck("../input_data/base_deck.json")
print(len(base_deck.cards))
# Out:
# 45

# %%
# --- test reshuffle method ---
print(len(base_deck.draw_pile))
print(len(base_deck.discard_pile))

print(base_deck.draw_pile[0 : 5])

#drawn = base_deck.draw(5)
#print(drawn, len(base_deck.draw_pile), sep="\n")

# --- test draw method ---
# Out:
# 45
# 0
# [
#  __________________
# |mouse card|
#  |costing 1_mouse|
#  |worth 0|
#  |gives |
#  codebreakers
# __________________
# ,
#  __________________
# |mouse card|
#  |costing 1_mouse|
#  |worth 0|
#  |gives |
#  codebreakers
# __________________
# ,
#  __________________
# |mouse card|
#  |costing 1_mouse|
#  |worth 2|
#  |gives tea|
#
# __________________
# ,
#  __________________
# |mouse card|
#  |costing 1_mouse|
#  |worth 1|
#  |gives bag|
#
# __________________
# ,
#  __________________
# |mouse card|
#  |costing 2_mouse|
#  |worth 0|
#  |gives |
#  scouting party
# __________________
# ]
